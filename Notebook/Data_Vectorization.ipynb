# %%
#For data preprocessing and vectorization
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("../Data/Final_Data.csv")
df1.drop(["Unnamed: 0"], axis=1, inplace=True) # drop "Unnamed:0" column
df1.head(5)
# Out:
#            artist                    song         genre  duration_min  \
# 0  Britney Spears  Oops!...I Did It Again           pop          3.52
# 1       blink-182    All The Small Things     rock, pop          2.78
# 2      Faith Hill                 Breathe  pop, country          4.18
# 3        Bon Jovi            It's My Life   rock, metal          3.74
# 4           NSYNC             Bye Bye Bye           pop          3.34
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# 1          79         0.434   0.897    0    -4.918     1       0.0488
# 2          66         0.529   0.496    7    -9.007     1       0.0290
# 3          78         0.551   0.913    0    -4.063     0       0.0466
# 4          65         0.614   0.928    8    -4.806     0       0.0516
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0        0.3000          0.000018    0.3550    0.894   95.053
# 1        0.0103          0.000000    0.6120    0.684  148.726
# 2        0.1730          0.000000    0.2510    0.278  136.859
# 3        0.0263          0.000013    0.3470    0.544  119.992
# 4        0.0408          0.001040    0.0845    0.879  172.656

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1941 entries, 0 to 1940
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            1941 non-null   object
#  1   song              1941 non-null   object
#  2   genre             1941 non-null   object
#  3   duration_min      1941 non-null   float64
#  4   popularity        1941 non-null   int64
#  5   danceability      1941 non-null   float64
#  6   energy            1941 non-null   float64
#  7   key               1941 non-null   int64
#  8   loudness          1941 non-null   float64
#  9   mode              1941 non-null   int64
#  10  speechiness       1941 non-null   float64
#  11  acousticness      1941 non-null   float64
#  12  instrumentalness  1941 non-null   float64
#  13  liveness          1941 non-null   float64
#  14  valence           1941 non-null   float64
#  15  tempo             1941 non-null   float64
# dtypes: float64(10), int64(3), object(3)
# memory usage: 242.8+ KB

# %%
df1.iloc[0,4:]
# Out:
# popularity                77
# danceability           0.751
# energy                 0.834
# key                        1
# loudness              -5.444
# mode                       0
# speechiness           0.0437
# acousticness             0.3
# instrumentalness    0.000018
# liveness               0.355
# valence                0.894
# tempo                 95.053
# Name: 0, dtype: object

# %%
from sklearn.metrics.pairwise import cosine_similarity
df1.iloc[0:-1,4:]

print(df1.song)
cosine_similarity([df1.iloc[0,4:]],df1.iloc[0:-1,4:])[0]
# Out:
# 0                       Oops!...I Did It Again
# 1                         All The Small Things
# 2                                      Breathe
# 3                                 It's My Life
# 4                                  Bye Bye Bye
#                          ...
# 1936                                    Sucker
# 1937                              Cruel Summer
# 1938                                The Git Up
# 1939    Dancing With A Stranger (with Normani)
# 1940                                   Circles
# Name: song, Length: 1941, dtype: object
# array([1.        , 0.98136013, 0.97255612, ..., 0.96790077, 0.99511985,
#        0.99705127])

# %%
df1["CosineSimilarity"]=cosine_similarity([df1.iloc[0,4:]],df1.iloc[:,4:])[0].tolist()
df1
# Out:
#               artist                                    song  \
# 0     Britney Spears                  Oops!...I Did It Again
# 1          blink-182                    All The Small Things
# 2         Faith Hill                                 Breathe
# 3           Bon Jovi                            It's My Life
# 4              NSYNC                             Bye Bye Bye
# ...              ...                                     ...
# 1936  Jonas Brothers                                  Sucker
# 1937    Taylor Swift                            Cruel Summer
# 1938    Blanco Brown                              The Git Up
# 1939       Sam Smith  Dancing With A Stranger (with Normani)
# 1940     Post Malone                                 Circles
#
#                  genre  duration_min  popularity  danceability  energy  key  \
# 0                  pop          3.52          77         0.751   0.834    1
# 1            rock, pop          2.78          79         0.434   0.897    0
# 2         pop, country          4.18          66         0.529   0.496    7
# 3          rock, metal          3.74          78         0.551   0.913    0
# 4                  pop          3.34          65         0.614   0.928    8
# ...                ...           ...         ...           ...     ...  ...
# 1936               pop          3.02          79         0.842   0.734    1
# 1937               pop          2.97          78         0.552   0.702    9
# 1938  hip hop, country          3.34          69         0.847   0.678    9
# 1939               pop          2.85          75         0.741   0.520    8
# 1940           hip hop          3.59          85         0.695   0.762    0
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0       -5.444     0       0.0437        0.3000          0.000018    0.3550
# 1       -4.918     1       0.0488        0.0103          0.000000    0.6120
# 2       -9.007     1       0.0290        0.1730          0.000000    0.2510
# 3       -4.063     0       0.0466        0.0263          0.000013    0.3470
# 4       -4.806     0       0.0516        0.0408          0.001040    0.0845
# ...        ...   ...          ...           ...               ...       ...
# 1936    -5.065     0       0.0588        0.0427          0.000000    0.1060
# 1937    -5.707     1       0.1570        0.1170          0.000021    0.1050
# 1938    -8.635     1       0.1090        0.0669          0.000000    0.2740
# 1939    -7.513     1       0.0656        0.4500          0.000002    0.2220
# 1940    -3.497     1       0.0395        0.1920          0.002440    0.0863
#
#       valence    tempo  CosineSimilarity
# 0       0.894   95.053          1.000000
# 1       0.684  148.726          0.981359
# 2       0.278  136.859          0.972556
# 3       0.544  119.992          0.994384
# 4       0.879  172.656          0.948305
# ...       ...      ...               ...
# 1936    0.952  137.958          0.987031
# 1937    0.564  169.994          0.967898
# 1938    0.811   97.984          0.995120
# 1939    0.347  102.998          0.997051
# 1940    0.553  120.042          0.997626
#
# [1941 rows x 17 columns]

# %%
df1.sort_values(by=["CosineSimilarity"],ascending=False)
# Out:
#               artist                                 song  \
# 0     Britney Spears               Oops!...I Did It Again
# 1552           Drake                            One Dance
# 1309  Ellie Goulding                                 Burn
# 1419            MKTO                              Classic
# 1813           Drake                       In My Feelings
# ...              ...                                  ...
# 1726           Drake                         Passionfruit
# 1201     Michel Teló              Ai Se Eu Te Pego - Live
# 1624      Tory Lanez                                  LUV
# 874           T-Pain  Can't Believe It (feat. Lil' Wayne)
# 1454      Nick Jonas                      Jealous - Remix
#
#                             genre  duration_min  popularity  danceability  \
# 0                             pop          3.52          77         0.751
# 1552            hip hop, pop, R&B          2.90          84         0.792
# 1309  pop, rock, Dance/Electronic          3.85          70         0.559
# 1419                 hip hop, pop          2.92          82         0.720
# 1813            hip hop, pop, R&B          3.63          75         0.835
# ...                           ...           ...         ...           ...
# 1726            hip hop, pop, R&B          4.98           0         0.809
# 1201               country, latin          2.78           0         0.676
# 1624            hip hop, pop, R&B          3.81           0         0.688
# 874             hip hop, pop, R&B          4.56           0         0.648
# 1454                          pop          3.70           0         0.685
#
#       energy  key  loudness  mode  speechiness  acousticness  \
# 0      0.834    1    -5.444     0       0.0437       0.30000
# 1552   0.625    1    -5.609     1       0.0536       0.00776
# 1309   0.777    1    -5.031     1       0.0432       0.31000
# 1419   0.791    1    -4.689     1       0.1240       0.03840
# 1813   0.626    1    -5.833     1       0.1250       0.05890
# ...      ...  ...       ...   ...          ...           ...
# 1726   0.463   11   -11.377     1       0.0396       0.25600
# 1201   0.935   11    -4.550     1       0.0692       0.35700
# 1624   0.541   11    -8.128     0       0.1140       0.01180
# 874    0.516   10    -8.869     0       0.0490       0.00179
# 1454   0.709   11    -3.578     0       0.0748       0.01320
#
#       instrumentalness  liveness  valence    tempo  CosineSimilarity
# 0             0.000018    0.3550   0.8940   95.053          1.000000
# 1552          0.001800    0.3290   0.3700  103.967          0.999952
# 1309          0.000000    0.1050   0.3290   87.016          0.999941
# 1419          0.000000    0.1570   0.7560  102.071          0.999919
# 1813          0.000060    0.3960   0.3500   91.030          0.999904
# ...                ...       ...      ...      ...               ...
# 1726          0.085000    0.1090   0.3640  111.980          0.773868
# 1201          0.000000    0.8530   0.8500   96.055          0.773370
# 1624          0.000000    0.1230   0.2470   95.109          0.773061
# 874           0.000000    0.0772   0.0756   89.828          0.773045
# 1454          0.000000    0.4520   0.5040   93.047          0.773011
#
# [1941 rows x 17 columns]
