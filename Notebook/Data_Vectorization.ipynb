# %%
#For data preprocessing and vectorization
import pandas as pd
import numpy as np

# %%
# Read Final_Data.csv file
df1 = pd.read_csv("../Data/Final_Data.csv")
df1.drop(["Unnamed: 0"], axis=1, inplace=True) # drop "Unnamed:0" column
df1.head(5)
# Out:
#            artist  year                    song         genre  duration_min  \
# 0  Britney Spears  2000  Oops!...I Did It Again           pop          3.52
# 1       blink-182  1999    All The Small Things     rock, pop          2.78
# 2      Faith Hill  1999                 Breathe  pop, country          4.18
# 3        Bon Jovi  2000            It's My Life   rock, metal          3.74
# 4           NSYNC  2000             Bye Bye Bye           pop          3.34
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# 1          79         0.434   0.897    0    -4.918     1       0.0488
# 2          66         0.529   0.496    7    -9.007     1       0.0290
# 3          78         0.551   0.913    0    -4.063     0       0.0466
# 4          65         0.614   0.928    8    -4.806     0       0.0516
#
#    acousticness  instrumentalness  liveness  valence    tempo
# ...

# %%
# All columns and their datatype
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1941 entries, 0 to 1940
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            1941 non-null   object
#  1   year              1941 non-null   int64
#  2   song              1941 non-null   object
#  3   genre             1941 non-null   object
#  4   duration_min      1941 non-null   float64
#  5   popularity        1941 non-null   int64
#  6   danceability      1941 non-null   float64
#  7   energy            1941 non-null   float64
#  8   key               1941 non-null   int64
#  9   loudness          1941 non-null   float64
#  10  mode              1941 non-null   int64
#  11  speechiness       1941 non-null   float64
#  12  acousticness      1941 non-null   float64
#  13  instrumentalness  1941 non-null   float64
#  14  liveness          1941 non-null   float64
#  15  valence           1941 non-null   float64
# ...

# %%
# Show only the numerical values
df1.iloc[0,4:]
# Out:
# duration_min            3.52
# popularity                77
# danceability           0.751
# energy                 0.834
# key                        1
# loudness              -5.444
# mode                       0
# speechiness           0.0437
# acousticness             0.3
# instrumentalness    0.000018
# liveness               0.355
# valence                0.894
# tempo                 95.053
# Name: 0, dtype: object

# %%
# Using Conine similarity to calculate simirarity factor ofall songs   
from sklearn.metrics.pairwise import cosine_similarity
df1.iloc[0:-1,4:]

print(df1.song)
cosine_similarity([df1.iloc[0,4:]],df1.iloc[:,4:])[0]
# Out:
# 0                       Oops!...I Did It Again
# 1                         All The Small Things
# 2                                      Breathe
# 3                                 It's My Life
# 4                                  Bye Bye Bye
#                          ...
# 1936                                    Sucker
# 1937                              Cruel Summer
# 1938                                The Git Up
# 1939    Dancing With A Stranger (with Normani)
# 1940                                   Circles
# Name: song, Length: 1941, dtype: object
# array([1.        , 0.98129549, 0.9725769 , ..., 0.99512321, 0.99703239,
#        0.99761889])

# %%
# Create a coloumn of Conine similarity
df1["CosineSimilarity"]=cosine_similarity([df1.iloc[0,4:]],df1.iloc[:,4:])[0].tolist()
df1
# Out:
#               artist  year                                    song  \
# 0     Britney Spears  2000                  Oops!...I Did It Again
# 1          blink-182  1999                    All The Small Things
# 2         Faith Hill  1999                                 Breathe
# 3           Bon Jovi  2000                            It's My Life
# 4              NSYNC  2000                             Bye Bye Bye
# ...              ...   ...                                     ...
# 1936  Jonas Brothers  2019                                  Sucker
# 1937    Taylor Swift  2019                            Cruel Summer
# 1938    Blanco Brown  2019                              The Git Up
# 1939       Sam Smith  2019  Dancing With A Stranger (with Normani)
# 1940     Post Malone  2019                                 Circles
#
#                  genre  duration_min  popularity  danceability  energy  key  \
# 0                  pop          3.52          77         0.751   0.834    1
# ...

# %%
# Sort Similarity by ascending way
df1.sort_values(by=["CosineSimilarity"],ascending=False)
# Out:
#               artist  year                                 song  \
# 0     Britney Spears  2000               Oops!...I Did It Again
# 1552           Drake  2016                            One Dance
# 1309  Ellie Goulding  2014                                 Burn
# 1813           Drake  2018                       In My Feelings
# 1419            MKTO  2012                              Classic
# ...              ...   ...                                  ...
# 1726           Drake  2017                         Passionfruit
# 1201     Michel Teló  2012              Ai Se Eu Te Pego - Live
# 1624      Tory Lanez  2016                                  LUV
# 1454      Nick Jonas  2014                      Jealous - Remix
# 874           T-Pain  2008  Can't Believe It (feat. Lil' Wayne)
#
#                             genre  duration_min  popularity  danceability  \
# 0                             pop          3.52          77         0.751
# ...

# %%
df=df1.sort_values(by=["CosineSimilarity"],ascending=False)
df["song"][:10]
# Out:
# 0                      Oops!...I Did It Again
# 1552                                One Dance
# 1309                                     Burn
# 1813                           In My Feelings
# 1419                                  Classic
# 1222    Young, Wild & Free (feat. Bruno Mars)
# 100                              It Wasn't Me
# 1760                                  Natural
# 1032                             Just A Dream
# 725                             About You Now
# Name: song, dtype: object

# %%
def get_song(title,df1):
    # 1. Based on the title get the song data from the dataframe
    song_index=df1[df1['song'] == title].index.values
    song_data=df1.iloc[song_index,4:]
    # 2. Compare the song data (vector) with all the dataframe 
    cosine=cosine_similarity(song_data,df1.iloc[:,4:])[0]
    # 3. Create a new coloumn with the cosine similarity
    df1["CosineSimilarity"]=cosine.tolist()
    # 4. Return top 10 songs based on cosine similarity
    score=df1.sort_values(by=["CosineSimilarity"],ascending=False)
    top10_songs=score["song"][1:11]
    top10_songs_list=top10_songs.values.tolist()
    return top10_songs_list

# %%
get_song("Oops!...I Did It Again", df1)
# Out:
# ['One Dance',
#  'Burn',
#  'In My Feelings',
#  'Classic',
#  'Young, Wild & Free (feat. Bruno Mars)',
#  "It Wasn't Me",
#  'Natural',
#  'Just A Dream',
#  'About You Now',
#  'Gold Digger']

# %%
song_list = df.Courses.values.tolist()
print(col_list)

# %%
#df1[song('Oops!...I Did It Again')]
#df1.loc[df['song'] == 'Oops!...I Did It Again']
song_index=df1[df['song'] == "In My Feelings"].index.values
song_data=df1.iloc[song_index,4:]
cosine=cosine_similarity(song_data,df1.iloc[:,4:])[0]
cosine.tolist()
#df1.iloc[df1.song,4:]
# Out:
# /tmp/ipykernel_22284/647873232.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   song_index=df1[df['song'] == "In My Feelings"].index.values
# [0.9999024299493441,
#  0.9795841518160634,
#  0.9707599289483616,
#  0.9933569789181055,
#  0.9455022322753027,
#  0.985128195365114,
#  0.9993793009102722,
#  0.9931497838179951,
#  0.9811193148029309,
#  0.9895517710759583,
#  0.7765925994500797,
#  0.9596315405694902,
#  0.9326710091383076,
#  0.9831043846632116,
#  0.9475406733292988,
#  0.9841928368240495,
#  0.9785593474990305,
#  0.9792086480347683,
#  0.9748736407748981,
#  0.9967253006316861,
#  0.9996195562481283,
#  0.9780868701714422,
#  0.9665000273254151,
#  0.9870717408160765,
#  0.9526519073567261,
#  0.9940224552331898,
#  0.9739816379093957,
#  0.9762906436738955,
#  0.9566102787101181,
#  0.9385674239281956,
#  0.9376572189221504,
#  0.9582458661908002,
#  0.9707842549084282,
#  0.9773692581091671,
#  0.9914354293731372,
# ...

# %%
# 1. Load the dataframe
uploads_dir = "/home/becode/BeCode Projects/Music_RecomendetionApp/Data/Final_Data.csv"
 #2. Ask the user for song title
print("please enter the song :", title="")
 # 3. Call the function to get songs
print("Recommended top 10 songs are:",get_song(title=""))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_22284/3425410764.py in <module>
#       2 uploads_dir = "/home/becode/BeCode Projects/Music_RecomendetionApp/Data/Final_Data.csv"
#       3  #2. Ask the user for song title
# ----> 4 print("please enter the song :", title="")
#       5  # 3. Call the function to get songs
#       6 print("Recommended top 10 songs are:",get_song(title=""))
#
# TypeError: 'title' is an invalid keyword argument for print()
